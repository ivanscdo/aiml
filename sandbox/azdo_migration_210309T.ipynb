# %%
import numpy as np
import pandas as pd

azdo_master = pd.read_csv('~/Desktop/azdo_migration__in_progress_2021-03-09T06_39_20-0600.csv')
azdo_master.head()
# Out:
#   Issue Type  Issue key  Issue id  \
# 0      Story  MKTG-1542   2597797
# 1      Story  MKTG-1541   2594866
# 2       Task  MKTG-1534   2579411
# 3      Story  MKTG-1533   2577710
# 4      Story  MKTG-1531   2576401
#
#                                              Summary  Assignee  \
# 0        6Sense:  Send order file load incrementally       NaN
# 1  Pardot Research:  Subscription and Preference ...  GRGiselT
# 2  Test of AMPSEA-related prospect-lead-contact s...  sandosza
# 3  Advertising team needs to be able to upload ag...  sandosza
# 4   Disable Assignment Rule Trigger for Leads in ELQ       NaN
#
#                   Status             Created            Updated  \
# 0  Ready for Development   22/Feb/21 2:19 AM  23/Feb/21 8:28 AM
# 1         In Development   17/Feb/21 9:35 AM  17/Feb/21 9:38 AM
# 2            In Progress   01/Feb/21 3:27 AM  03/Feb/21 4:56 AM
# 3         In Development  29/Jan/21 11:00 AM  11/Feb/21 8:40 AM
# ...

# %%
azdo_master.loc[:, 'Issue key': 'Summary'].drop('Issue id', 1)
# Out:
#     Issue key                                            Summary
# 0   MKTG-1542        6Sense:  Send order file load incrementally
# 1   MKTG-1541  Pardot Research:  Subscription and Preference ...
# 2   MKTG-1534  Test of AMPSEA-related prospect-lead-contact s...
# 3   MKTG-1533  Advertising team needs to be able to upload ag...
# 4   MKTG-1531   Disable Assignment Rule Trigger for Leads in ELQ
# 5   MKTG-1529   Pardot: Research activities integration solution
# 6   MKTG-1528  Pardot: Transactional Email Comms (nimarcomws ...
# 7   MKTG-1527           Pardot: Data Ingestion (Pardot into EDL)
# 8   MKTG-1526  Pardot:  Contact Migration file preparation ba...
# 9   MKTG-1524                             Migrate Assets in SFDC
# 10  MKTG-1510  Lattice Q1 | Load active contacts for Q1 2021 ...
# 11  MKTG-1504                              Events pages redesign
# 12  MKTG-1497  Research:  Eloqua native integration de-suppor...
# ...
