# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from PIL import Image

# %%
data01 = pd.read_csv('../files/Melbourne_housing_FULL.csv')
data01.head()
# Out:
#          Suburb           Address  Rooms Type Method        SellerG      Date  \
# 0    Abbotsford     68 Studley St      2    h     SS         Jellis  3/9/2016
# 1  Airport West     154 Halsey Rd      3    t     PI         Nelson  3/9/2016
# 2   Albert Park    105 Kerferd Rd      2    h      S  hockingstuart  3/9/2016
# 3   Albert Park  85 Richardson St      2    h      S        Thomson  3/9/2016
# 4    Alphington      30 Austin St      3    h     SN        McGrath  3/9/2016
#
#    Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0      2.0  ...     126.0           inf        NaN
# 1      13.5    3042.0      3.0  ...     303.0           225     2016.0
# 2       3.3    3206.0      2.0  ...     120.0            82     1900.0
# 3       3.3    3206.0      2.0  ...     159.0           inf        NaN
# 4       6.4    3078.0      3.0  ...     174.0           122     2003.0
#
# ...

# %%
data01.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21097
# YearBuilt        19306
# CouncilArea          3
# Latitude          7976
# Longtitude        7976
# Regionname           0
# Propertycount        3
# ParkingArea          0
# Price             7610
# dtype: int64

# %%
data01 = data01.dropna()

# %%
data01.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom          0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Latitude         0
# Longtitude       0
# Regionname       0
# Propertycount    0
# ParkingArea      0
# Price            0
# dtype: int64

# %%
sns.pairplot(data01) # (!)slows down notebook

# %%
sns.scatterplot(data01['Price'], data01['Distance'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Distance'>

# %%
data01.corr() # correlation
# negative relation between distance and price; as distance goes up, price goes down
# positive correlation between price and number of rooms

# %%
sns.heatmap(data01.corr(), annot=True)
# same as correlation matrix but with colors

# %%
sns.scatterplot(data01['Distance'], data01['Price'], hue=data01['Type'], palette='Set2')
# take deeper look at price and distance
# third variable is Type
